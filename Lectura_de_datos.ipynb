# %% [markdown]
# # Introducción a la Innovación disruptiva
#
# ## Creación de bases de datos
#
# ![Image](
# https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExNzRyNHZ1bDRxYndicHMyYnQ4Nnc0aDB1a3J0c2o3enI3cm9xM203dCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/b4K0MfAZNLiQDqgYJN/giphy.gif)

# %%
top_startups = {
  "top_startups_2024": [
    {
      "rank": 1,
      "name": "OpenAI",
      "industry": "Artificial Intelligence",
      "valuation_usd_billions": 80,
      "headquarters": "San Francisco, USA",
      "key_products": ["ChatGPT", "GPT-4", "DALL-E"],
      "founders": ["Elon Musk", "Sam Altman", "Ilya Sutskever"],
      "year_founded": 2015
    },
    {
      "rank": 2,
      "name": "SpaceX",
      "industry": "Aerospace",
      "valuation_usd_billions": 150,
      "headquarters": "Hawthorne, USA",
      "key_products": ["Falcon Rockets", "Starlink", "Starship"],
      "founders": ["Elon Musk"],
      "year_founded": 2002
    },
    {
      "rank": 3,
      "name": "Stripe",
      "industry": "Fintech",
      "valuation_usd_billions": 65,
      "headquarters": "San Francisco, USA",
      "key_products": ["Payment Processing", "Stripe Connect"],
      "founders": ["Patrick Collison", "John Collison"],
      "year_founded": 2010
    },
    {
      "rank": 4,
      "name": "Canva",
      "industry": "Design Software",
      "valuation_usd_billions": 40,
      "headquarters": "Sydney, Australia",
      "key_products": ["Canva Design Platform", "Canva Pro"],
      "founders": ["Melanie Perkins", "Cliff Obrecht", "Cameron Adams"],
      "year_founded": 2012
    },
    {
      "rank": 5,
      "name": "Databricks",
      "industry": "Data & AI",
      "valuation_usd_billions": 43,
      "headquarters": "San Francisco, USA",
      "key_products": ["Databricks Lakehouse", "MLflow"],
      "founders": ["Ali Ghodsi", "Matei Zaharia", "Ion Stoica"],
      "year_founded": 2013
    },
    {
      "rank": 6,
      "name": "Discord",
      "industry": "Communication",
      "valuation_usd_billions": 15,
      "headquarters": "San Francisco, USA",
      "key_products": ["Discord App", "Nitro Subscription"],
      "founders": ["Jason Citron", "Stan Vishnevskiy"],
      "year_founded": 2015
    },
    {
      "rank": 7,
      "name": "Epic Games",
      "industry": "Gaming & Metaverse",
      "valuation_usd_billions": 32,
      "headquarters": "Cary, USA",
      "key_products": ["Unreal Engine", "Fortnite"],
      "founders": ["Tim Sweeney"],
      "year_founded": 1991
    },
    {
      "rank": 8,
      "name": "Rivian",
      "industry": "Electric Vehicles",
      "valuation_usd_billions": 25,
      "headquarters": "Irvine, USA",
      "key_products": ["R1T Truck", "R1S SUV"],
      "founders": ["RJ Scaringe"],
      "year_founded": 2009
    },
    {
      "rank": 9,
      "name": "ByteDance",
      "industry": "Social Media & AI",
      "valuation_usd_billions": 300,
      "headquarters": "Beijing, China",
      "key_products": ["TikTok", "Douyin"],
      "founders": ["Zhang Yiming"],
      "year_founded": 2012
    },
    {
      "rank": 10,
      "name": "Deel",
      "industry": "HR & Remote Work",
      "valuation_usd_billions": 12,
      "headquarters": "San Francisco, USA",
      "key_products": ["Global Payroll", "Contract Management"],
      "founders": ["Alex Bouaziz", "Shuo Wang"],
      "year_founded": 2018
    }
  ],
  "source": "Forbes, CB Insights (2024)",
  "note": "Valuations and rankings are approximate and subject to change."
}

# %%
EID_701 = {"Rodrigo":[21, "soltero", "Valeria",1.70], "Sam": [21, "soltera", "Blee", 1.67], "Luis": [20, "soltero", "angie", 1.65]}

# %%
EID_701.values()
# Out:
# dict_values([[21, 'soltero', 'Valeria', 1.7], [21, 'soltera', 'Blee', 1.67], [20, 'soltero', 'angie', 1.65]])

# %%
import pandas as pd
pd.DataFrame(EID_701)
# Out:
#    Rodrigo      Sam     Luis
# 0       21       21       20
# 1  soltero  soltera  soltero
# 2  Valeria     Blee    angie
# 3      1.7     1.67     1.65

# %%
import pandas as pd

DF_701 = pd.DataFrame(EID_701, index=["Edad","Estado civil","Pareja","Altura"])

# %%
# ¿Cuáles son los datos de Sam?
DF_701["Sam"]
# Out:
# Edad                 21
# Estado civil    soltera
# Pareja             Blee
# Altura             1.67
# Name: Sam, dtype: object

# %%
# ¿Cuáles son los datos de Sam?
DF_701["Sam"][0]
# Out:
# /tmp/ipython-input-1219047621.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   DF_701["Sam"][0]
# 21

# %%
list(top_startups.values())
# Out:
# [[{'rank': 1,
#    'name': 'OpenAI',
#    'industry': 'Artificial Intelligence',
#    'valuation_usd_billions': 80,
#    'headquarters': 'San Francisco, USA',
#    'key_products': ['ChatGPT', 'GPT-4', 'DALL-E'],
#    'founders': ['Elon Musk', 'Sam Altman', 'Ilya Sutskever'],
#    'year_founded': 2015},
#   {'rank': 2,
#    'name': 'SpaceX',
#    'industry': 'Aerospace',
#    'valuation_usd_billions': 150,
#    'headquarters': 'Hawthorne, USA',
#    'key_products': ['Falcon Rockets', 'Starlink', 'Starship'],
#    'founders': ['Elon Musk'],
#    'year_founded': 2002},
#   {'rank': 3,
#    'name': 'Stripe',
#    'industry': 'Fintech',
#    'valuation_usd_billions': 65,
#    'headquarters': 'San Francisco, USA',
#    'key_products': ['Payment Processing', 'Stripe Connect'],
#    'founders': ['Patrick Collison', 'John Collison'],
#    'year_founded': 2010},
#   {'rank': 4,
#    'name': 'Canva',
#    'industry': 'Design Software',
#    'valuation_usd_billions': 40,
# ...

# %% [markdown]
# # Bases de datos

# %%
estudiantes = {"Sam":[3,4,5.9,8,3.3],
               "Rangel":[7.7,8.0,8.2,9,9],
               "Zarate":[0,10,8,3.5,0],
               "Ricardo":[3,6.2,7,2,8]}

# %%
estudiantes
# Out:
# {'Sam': [3, 4, 5.9, 8, 3.3],
#  'Angel': [-1.5, 0, 2, 5, 10],
#  'Rangel': [7.7, 8.0, 8.2, 9, 9],
#  'Zarate': [0, 10, 8, 3.5, 0],
#  'Ricardo': [3, 6.2, 7, 2, 8]}

# %%
import pandas as pd

tablita = pd.DataFrame(estudiantes)

# %%
tablita
# Out:
#    Sam  Angel  Rangel  Zarate  Ricardo
# 0  3.0   -1.5     7.7     0.0      3.0
# 1  4.0    0.0     8.0    10.0      6.2
# 2  5.9    2.0     8.2     8.0      7.0
# 3  8.0    5.0     9.0     3.5      2.0
# 4  3.3   10.0     9.0     0.0      8.0

# %%
tablita.describe()
# Out:
#             Sam      Angel    Rangel     Zarate   Ricardo
# count  5.000000   5.000000  5.000000   5.000000  5.000000
# mean   4.840000   3.100000  8.380000   4.300000  5.240000
# std    2.095948   4.560702  0.593296   4.577117  2.605379
# min    3.000000  -1.500000  7.700000   0.000000  2.000000
# 25%    3.300000   0.000000  8.000000   0.000000  3.000000
# 50%    4.000000   2.000000  8.200000   3.500000  6.200000
# 75%    5.900000   5.000000  9.000000   8.000000  7.000000
# max    8.000000  10.000000  9.000000  10.000000  8.000000

# %%
import seaborn as sns

sns.boxplot(data=tablita)
# Out:
# <Axes: >

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = px.box(tablita,
             title="📊 Distribución de Calificaciones por Estudiante",
             labels={"value": "Calificación", "variable": "Estudiante"})

# Personalizar el gráfico
fig.update_layout(
    template="plotly_white",
    font=dict(size=12),
    hovermode="x unified",
    height=600,
    width=800
)

fig.update_traces(boxpoints='all', jitter=0.3, pointpos=-1.8)  # Mostrar todos los puntos

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
